# %%
import pandas as pd

# %%
dt=pd.read_csv("merged_crime_zip_hood.csv")

dt.head()
# Out:
#    Unnamed: 0  CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0           0   314773184           48      BRONX   12/31/2019     18:00:00
# 1           1   289837961           25  MANHATTAN   12/30/2019     20:30:00
# 2           2   535744284           77   BROOKLYN   12/24/2019     16:55:00
# 3           3   895678119           52      BRONX   12/30/2019     19:32:00
# 4           4   299841674           18  MANHATTAN   12/30/2019     15:30:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  ...  Latitude_x  \
# 0          NaN          NaN        COMPLETED        NaN  ...   40.838026
# 1   12/31/2019     10:00:00        COMPLETED        NaN  ...   40.800334
# 2   12/24/2019     17:00:00        COMPLETED        NaN  ...   40.669832
# 3          NaN          NaN        COMPLETED        NaN  ...   40.873671
# 4   12/30/2019     16:50:00        COMPLETED        NaN  ...   40.760935
#
# ...

# %%
dt["State"]="NY"

# %%
col_list=list(dt.columns)
print(col_list)
# Out:
# ['Unnamed: 0', 'CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD', 'HADEVELOPT', 'HOUSING_PSA', 'JURISDICTION_CODE', 'JURIS_DESC', 'KY_CD', 'LAW_CAT_CD', 'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PARKS_NM', 'PATROL_BORO', 'PD_CD', 'PD_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'STATION_NAME', 'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude_x', 'Longitude_x', 'Lat_Lon', 'geo2', 'geo4_x', 'geo3_x', 'Month', 'Year', 'Incident Zip', 'neighbourhood', 'State']

# %%
dt=dt[['CMPLNT_NUM', 'CMPLNT_FR_DT', 'Month', 'Year', 'CMPLNT_FR_TM', 'BORO_NM','State', 'Incident Zip', 'neighbourhood', 
        'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX', 
         'LAW_CAT_CD', 'OFNS_DESC', 'CRM_ATPT_CPTD_CD']]

# %%
dt.tail(10)
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT  Month  Year CMPLNT_FR_TM    BORO_NM State  \
# 461701   912917376     1/4/2019      1  2019     10:10:00  MANHATTAN    NY
# 461702   169145455     1/3/2019      1  2019      9:00:00  MANHATTAN    NY
# 461703   153186437     1/5/2019      1  2019     19:30:00  MANHATTAN    NY
# 461704   781940970     1/5/2019      1  2019      8:45:00     QUEENS    NY
# 461705   352845293     1/4/2019      1  2019      3:30:00  MANHATTAN    NY
# 461706   892593560     1/3/2019      1  2019     16:29:00   BROOKLYN    NY
# 461707   249722424     1/2/2019      1  2019     22:40:00     QUEENS    NY
# 461708   214650701     1/5/2019      1  2019     20:30:00   BROOKLYN    NY
# 461709   172836038     1/4/2019      1  2019      5:15:00  MANHATTAN    NY
# 461710   578287486     1/2/2018      1  2018     14:10:00      BRONX    NY
#
#         Incident Zip      neighbourhood SUSP_AGE_GROUP SUSP_RACE SUSP_SEX  \
# ...

# %%
col_list=list(dt.columns)
print(col_list)
# Out:
# ['CMPLNT_NUM', 'CMPLNT_FR_DT', 'Month', 'Year', 'CMPLNT_FR_TM', 'BORO_NM', 'State', 'Incident Zip', 'neighbourhood', 'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX', 'LAW_CAT_CD', 'OFNS_DESC', 'CRM_ATPT_CPTD_CD']

# %%
dt["Year"].unique()
# Out:
# array([2019, 2015, 1995, 2018, 2017, 2010, 2009, 2014, 2016, 1987, 2011,
#        2004, 2013, 1997, 2001, 1911, 2012, 1994, 2005, 1983, 2008, 1978,
#        2003, 1993, 1980, 1979, 1919, 1019, 1991, 1974, 2006, 2000, 1977,
#        1990, 1999, 2007, 1984, 1029, 1998, 1920, 1949, 1996, 2002, 1965,
#        1985, 1988, 1972, 1970, 1975, 1992, 1971, 1989, 1960, 1982, 1981,
#        1918, 1018], dtype=int64)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461711 entries, 0 to 461710
# Data columns (total 18 columns):
# CMPLNT_NUM          461711 non-null int64
# CMPLNT_FR_DT        461711 non-null object
# Month               461711 non-null int64
# Year                461711 non-null int64
# CMPLNT_FR_TM        461711 non-null object
# BORO_NM             461711 non-null object
# State               461711 non-null object
# Incident Zip        448495 non-null float64
# neighbourhood       450111 non-null object
# SUSP_AGE_GROUP      352301 non-null object
# SUSP_RACE           352301 non-null object
# SUSP_SEX            352301 non-null object
# VIC_AGE_GROUP       461708 non-null object
# VIC_RACE            461708 non-null object
# VIC_SEX             461708 non-null object
# LAW_CAT_CD          461711 non-null object
# OFNS_DESC           461699 non-null object
# CRM_ATPT_CPTD_CD    461711 non-null object
# dtypes: float64(1), int64(3), object(14)
# memory usage: 63.4+ MB

# %%
dt["Year"]=dt["Year"].astype(str)

# %%
dt.drop(dt[dt["Year"]!="2019"].index, inplace=True)

# %%
dt["Year"].unique()
# Out:
# array(['2019'], dtype=object)

# %%
dt.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT  Month  Year CMPLNT_FR_TM    BORO_NM State  \
# 0   314773184   12/31/2019     12  2019     18:00:00      BRONX    NY
# 1   289837961   12/30/2019     12  2019     20:30:00  MANHATTAN    NY
# 2   535744284   12/24/2019     12  2019     16:55:00   BROOKLYN    NY
# 3   895678119   12/30/2019     12  2019     19:32:00      BRONX    NY
# 4   299841674   12/30/2019     12  2019     15:30:00  MANHATTAN    NY
#
#    Incident Zip   neighbourhood SUSP_AGE_GROUP SUSP_RACE SUSP_SEX  \
# 0       10460.0         Tremont        UNKNOWN   UNKNOWN        U
# 1       10029.0          Harlem            NaN       NaN      NaN
# 2       11213.0   Crown Heights        UNKNOWN     BLACK        M
# 3       10463.0     Kingsbridge          25-44     WHITE        F
# 4       10036.0  Hell's Kitchen            NaN       NaN      NaN
#
#   VIC_AGE_GROUP        VIC_RACE VIC_SEX   LAW_CAT_CD       OFNS_DESC  \
# 0         45-64  WHITE HISPANIC       F       FELONY         ROBBERY
# ...

# %%
dt=dt.dropna(subset=["Incident Zip"])

# %%
dt["Incident Zip"]=dt["Incident Zip"].astype(int)

# %%
dt["Incident Zip"]=dt["Incident Zip"].astype(str)

# %%
 #we have 13,216 empty rows in col zipcodes but only 6,486 mising in "neighbourhood"

null_columns=dt.columns[dt.isnull().any()]
dt[null_columns].isnull().sum()
# Out:
# neighbourhood       8788
# SUSP_AGE_GROUP    101668
# SUSP_RACE         101668
# SUSP_SEX          101668
# VIC_AGE_GROUP          3
# VIC_RACE               3
# VIC_SEX                3
# OFNS_DESC              8
# dtype: int64

# %%
dt=dt.dropna(subset=["neighbourhood"])

# %%
dt=dt.dropna(subset=["OFNS_DESC"])

# %%
dt=dt.dropna(subset=["neighbourhood"])

# %%
dt.head(20)
# Out:
#     CMPLNT_NUM CMPLNT_FR_DT  Month  Year CMPLNT_FR_TM    BORO_NM State  \
# 0    314773184   12/31/2019     12  2019     18:00:00      BRONX    NY
# 1    289837961   12/30/2019     12  2019     20:30:00  MANHATTAN    NY
# 2    535744284   12/24/2019     12  2019     16:55:00   BROOKLYN    NY
# 3    895678119   12/30/2019     12  2019     19:32:00      BRONX    NY
# 4    299841674   12/30/2019     12  2019     15:30:00  MANHATTAN    NY
# 5    136697381   12/28/2019     12  2019     13:00:00   BROOKLYN    NY
# 6    628084657   12/22/2019     12  2019     16:30:00   BROOKLYN    NY
# 7    487138011   12/29/2019     12  2019     17:20:00      BRONX    NY
# 8    227601821   12/29/2019     12  2019     12:30:00  MANHATTAN    NY
# 9    536304115   12/28/2019     12  2019     15:05:00  MANHATTAN    NY
# 10   355744896   12/28/2019     12  2019     14:10:00      BRONX    NY
# 11   754294853   12/28/2019     12  2019     11:30:00  MANHATTAN    NY
# ...

# %%
# cleaning some other attributes like age

# %%
dt["SUSP_AGE_GROUP"].unique()
# Out:
# array(['UNKNOWN', nan, '25-44', '65+', '45-64', '18-24', '<18', '-965',
#        '2019', '-966', '-964', '-973', '-968', '-64', '930', '-1', '-80',
#        '947', '924', '929', '1019'], dtype=object)

# %%
dt.groupby(["SUSP_AGE_GROUP"]).agg({"CMPLNT_NUM":"count"})
# Out:
#                 CMPLNT_NUM
# SUSP_AGE_GROUP
# -1                       2
# -64                      1
# -80                      1
# -964                     1
# -965                     1
# -966                     2
# -968                     2
# -973                     2
# 1019                     1
# 18-24                36595
# 2019                     8
# 25-44               110686
# 45-64                40220
# 65+                   3738
# 924                      1
# 929                      2
# 930                      1
# 947                      1
# <18                  11274
# UNKNOWN             128031

# %%
drop_index=dt[(dt["SUSP_AGE_GROUP"]!="45-64") & (dt["SUSP_AGE_GROUP"]!="25-44")&
                    (dt["SUSP_AGE_GROUP"]!="18-24") & (dt["SUSP_AGE_GROUP"]!="65+")&
                   (dt["SUSP_AGE_GROUP"]!="<18")& (dt["SUSP_AGE_GROUP"]!="UNKNOWN")].index

dt.drop(drop_index , inplace=True)
dt["SUSP_AGE_GROUP"].unique()
# Out:
# array(['UNKNOWN', '25-44', '65+', '45-64', '18-24', '<18'], dtype=object)

# %%
drop_index=dt[(dt["VIC_AGE_GROUP"]!="45-64") & (dt["VIC_AGE_GROUP"]!="25-44")&
                    (dt["VIC_AGE_GROUP"]!="18-24") & (dt["VIC_AGE_GROUP"]!="65+")&
                   (dt["VIC_AGE_GROUP"]!="<18")& (dt["VIC_AGE_GROUP"]!="UNKNOWN")].index

dt.drop(drop_index , inplace=True)
dt["SUSP_AGE_GROUP"].unique()
# Out:
# array(['UNKNOWN', '25-44', '65+', '45-64', '18-24', '<18'], dtype=object)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330517 entries, 0 to 461707
# Data columns (total 18 columns):
# CMPLNT_NUM          330517 non-null int64
# CMPLNT_FR_DT        330517 non-null object
# Month               330517 non-null int64
# Year                330517 non-null object
# CMPLNT_FR_TM        330517 non-null object
# BORO_NM             330517 non-null object
# State               330517 non-null object
# Incident Zip        330517 non-null object
# neighbourhood       330517 non-null object
# SUSP_AGE_GROUP      330517 non-null object
# SUSP_RACE           330517 non-null object
# SUSP_SEX            330517 non-null object
# VIC_AGE_GROUP       330517 non-null object
# VIC_RACE            330517 non-null object
# VIC_SEX             330517 non-null object
# LAW_CAT_CD          330517 non-null object
# OFNS_DESC           330517 non-null object
# CRM_ATPT_CPTD_CD    330517 non-null object
# dtypes: int64(2), object(16)
# memory usage: 47.9+ MB

# %%
dt["Month"]=dt["Month"].astype(str)

# %%
dt["CMPLNT_NUM"]=dt["CMPLNT_NUM"].astype(str)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330517 entries, 0 to 461707
# Data columns (total 18 columns):
# CMPLNT_NUM          330517 non-null object
# CMPLNT_FR_DT        330517 non-null object
# Month               330517 non-null object
# Year                330517 non-null object
# CMPLNT_FR_TM        330517 non-null object
# BORO_NM             330517 non-null object
# State               330517 non-null object
# Incident Zip        330517 non-null object
# neighbourhood       330517 non-null object
# SUSP_AGE_GROUP      330517 non-null object
# SUSP_RACE           330517 non-null object
# SUSP_SEX            330517 non-null object
# VIC_AGE_GROUP       330517 non-null object
# VIC_RACE            330517 non-null object
# VIC_SEX             330517 non-null object
# LAW_CAT_CD          330517 non-null object
# OFNS_DESC           330517 non-null object
# CRM_ATPT_CPTD_CD    330517 non-null object
# dtypes: object(18)
# memory usage: 47.9+ MB

# %%
dt.rename(columns={"CRM_ATPT_CPTD_CD":"CrimeSuccesOrNot", "CMPLNT_FR_DT":"DateOfCrime", 
                     "CMPLNT_FR_TM":"TimeOfCrime" , "LAW_CAT_CD":"CrimeCategory", "OFNS_DESC":"CrimeDescription"})
# Out:
#        CMPLNT_NUM DateOfCrime Month  Year TimeOfCrime    BORO_NM State  \
# 0       314773184  12/31/2019    12  2019    18:00:00      BRONX    NY
# 2       535744284  12/24/2019    12  2019    16:55:00   BROOKLYN    NY
# 3       895678119  12/30/2019    12  2019    19:32:00      BRONX    NY
# 6       628084657  12/22/2019    12  2019    16:30:00   BROOKLYN    NY
# 7       487138011  12/29/2019    12  2019    17:20:00      BRONX    NY
# ...           ...         ...   ...   ...         ...        ...   ...
# 461700  710094784    1/1/2019     1  2019     1:40:00      BRONX    NY
# 461701  912917376    1/4/2019     1  2019    10:10:00  MANHATTAN    NY
# 461704  781940970    1/5/2019     1  2019     8:45:00     QUEENS    NY
# 461705  352845293    1/4/2019     1  2019     3:30:00  MANHATTAN    NY
# 461707  249722424    1/2/2019     1  2019    22:40:00     QUEENS    NY
#
#        Incident Zip      neighbourhood SUSP_AGE_GROUP       SUSP_RACE  \
# ...

# %%
dt.to_csv("FinalCrime.csv")

# %%
dt.shape
# Out:
# (330517, 18)

# %% [markdown]
# ## creating small csv's

# %%
#date dimension

# %%
date_dimension=pd.read_csv("FinalCrime.csv")

# %%
date_dimension.head()
# Out:
#    Unnamed: 0  CMPLNT_NUM CMPLNT_FR_DT  Month  Year CMPLNT_FR_TM   BORO_NM  \
# 0           0   314773184   12/31/2019     12  2019     18:00:00     BRONX
# 1           2   535744284   12/24/2019     12  2019     16:55:00  BROOKLYN
# 2           3   895678119   12/30/2019     12  2019     19:32:00     BRONX
# 3           6   628084657   12/22/2019     12  2019     16:30:00  BROOKLYN
# 4           7   487138011   12/29/2019     12  2019     17:20:00     BRONX
#
#   State  Incident Zip  neighbourhood SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX  \
# 0    NY         10460        Tremont        UNKNOWN         UNKNOWN        U
# 1    NY         11213  Crown Heights        UNKNOWN           BLACK        M
# 2    NY         10463    Kingsbridge          25-44           WHITE        F
# 3    NY         11236       Canarsie          25-44           BLACK        M
# 4    NY         10472    Parkchester        UNKNOWN  WHITE HISPANIC        M
#
# ...

# %%
name_list=list(date_dimension.columns)
print(name_list)
# Out:
# ['CMPLNT_NUM', 'CMPLNT_FR_DT', 'Month', 'Year', 'CMPLNT_FR_TM', 'BORO_NM', 'State', 'Incident Zip', 'neighbourhood', 'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX', 'LAW_CAT_CD', 'OFNS_DESC', 'CRM_ATPT_CPTD_CD']

# %%
date_dimension=date_dimension[['CMPLNT_NUM', 'CMPLNT_FR_DT', 'Month', 'Year', 'CMPLNT_FR_TM']]
date_dimension.tail()
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT  Month  Year CMPLNT_FR_TM
# 330512   710094784     1/1/2019      1  2019      1:40:00
# 330513   912917376     1/4/2019      1  2019     10:10:00
# 330514   781940970     1/5/2019      1  2019      8:45:00
# 330515   352845293     1/4/2019      1  2019      3:30:00
# 330516   249722424     1/2/2019      1  2019     22:40:00

# %%
date_dimension.to_csv("DateDimension.csv")

# %%
# crime dimension

# %%
crime_dimension=pd.read_csv("FinalCrime.csv")

# %%
crime_dimension=crime_dimension[['CMPLNT_NUM','LAW_CAT_CD', 'OFNS_DESC', 'CRM_ATPT_CPTD_CD']]

# %%
crime_dimension.head()
# Out:
#    CMPLNT_NUM   LAW_CAT_CD                     OFNS_DESC CRM_ATPT_CPTD_CD
# 0   314773184       FELONY                       ROBBERY        COMPLETED
# 1   535744284       FELONY                FELONY ASSAULT        COMPLETED
# 2   895678119  MISDEMEANOR                 PETIT LARCENY        COMPLETED
# 3   628084657  MISDEMEANOR  ASSAULT 3 & RELATED OFFENSES        COMPLETED
# 4   487138011       FELONY                       ROBBERY        COMPLETED

# %%
crime_dimension.to_csv("CrimeTypeDimension.csv")
